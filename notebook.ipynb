# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*

# %% [markdown]
# ## Data Validation
# This dataset contains 15000 rows and 8 columns before cleaning and validation. All the columns have been validated against the criteria in the dataset table :
# - week :- 6 distinct numeric values without missing values, cleaning not required.
# - sales_method :- Replaced 'em + call' with 'Email + Call' and 'email' with 'Email'. 3 distinct text values after preprocessing.
# - customer_id :- unique string values for each row without missing values, cleaning not required.
# - nb_sold :- 10 distinct numeric values ranging from 7 to 16, cleaning not required.
# - revenue :- numeric values, filled up the 'NA' values using Fill Up.
# - years_as_customer :- numeric values ranging from 0 to 39, drop rows having value not in the range.
# - nb_site_visits :- numeric values ranging from 15 to 41, cleaning not required.
# - state :- 50 distinct text values, no cleaning required.
#
# After the data validation dataset has 14998 rows and 8 columns.

# %% [markdown]
# ## Number of customers with different approach
# Here we can see that 7465 sales has been completed through 'Email' Method. Which is higher than any other sales methods. 4961 sales has been completed through 'Call' method, and 2572 sales has been completed by 'Email+Call' method.
# ![Screenshot 2024-08-22 191246](Screenshot%202024-08-22%20191246.png)

# %% [markdown]
# ## Distribution of Revenue
#
# ### Here is the overall distribution of revenues.
# There are more than one peak for the distribution.
# ![Screenshot 2024-08-22 190034](Screenshot%202024-08-22%20190034.png)
#
# ### Here is the distribution of Revenue for 'Call' Method
# The distribution is right skewed
# ![Screenshot 2024-08-22 190137](Screenshot%202024-08-22%20190137.png)
#
# ### Here is the distribution of Revenue for 'Email' Method
# ![Screenshot 2024-08-22 190334](Screenshot%202024-08-22%20190334.png)
#
# ### Here is the distribution of Revenue for 'Email + Call' Method
# The distribution is left skewed
# ![Screenshot 2024-08-22 190436](Screenshot%202024-08-22%20190436.png)
#
# ### Here is the distribution of revenue by each methods using boxplot
# ![Screenshot 2024-08-22 191825](Screenshot%202024-08-22%20191825.png)

# %% [markdown]
# ## Number of Sales over nb_site_visits
#
# In this visual I have plotted the distribution of nb_site_visits. Here we can see that the distributions are bell shaped and number of sales for 'Email' method is larger than other  method for each value of **nb_site_visits**.
# ![Screenshot 2024-08-22 172124](Screenshot%202024-08-22%20172124.png)

# %% [markdown]
# ## Revenue by year_as_customer
#
# In this plot we can easily see that **Average Revenue** for 'Email + Call' method is **larger** than other method for each value except last one of **year_as_customer**
# ![Screenshot 2024-08-22 190721](Screenshot%202024-08-22%20190721.png)

# %% [markdown]
# ## Revenue by time (week)
# By this line chart we can say that **Average revenue** for 'Email + Call' is larger than other methods for each value of week.
# ![Screenshot 2024-08-22 190838](Screenshot%202024-08-22%20190838.png)

# %% [markdown]
# ## Business goals
# 1. Analyze data for the first six weeks of sales from the new
# product line.
# 2. Determine the effectiveness of three different methods
# of customer interaction with regards to the new product
# line.
# 3. Provide recommendations for use of these methods
# going forward, including a metric on how to define
# success.

# %% [markdown]
# ## Business metrics
# - Business metrics for this problem is **Average revenue by methods per week**.
# - Average revenue per week of 'Email+Call' method is 160.70
# - Average revenue per week of 'Email' method is 104.25
# - Average revenue per week of 'Call' method is 50.18
# - Average revenue per week of 'Email+Call' method is larger than other methods.
# - So, we can conclude that 'Email+Call' is the best method to maximize revenue.

# %% [markdown]
# ## Recommendations
# I would recommend the company to
# 1. increase focus on 'Email+Call' approach in campaign.
# 2. decrease focus on 'Call' approach in campaign as it is time consuming.
# 3. Improve data collection practices, there was 1074 missing values in revenue colummn.
# 4. not include values in year_as_customer that are not in the range of 0 to 39.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation
